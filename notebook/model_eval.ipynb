# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loss_baseline = np.load('../model/loss_baseline.npy')
loss_state = np.load('../model/loss_state.npy')

len(loss_baseline), len(loss_state)
# Out:
# (31114, 7783)

# %%
loss_baseline = loss_baseline[:5000]
loss_state = loss_state[:5000]
df = pd.DataFrame({'baseline': loss_baseline, 'state': loss_state})

# %%
loss_baseline[:-900].mean()
# Out:
# 2628.7350363957034

# %%
fig = plt.figure(figsize=(13, 6))
sns.lineplot(data=df[:10000])
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend(title='Model')
plt.tight_layout()
plt.savefig('../figure/loss0429.png')
plt.show()
# Out:
# /home/shaoze/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/shaoze/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
